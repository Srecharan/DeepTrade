# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append('..')
from models.train import train_model

# Load data
X_train = np.load('../data/processed/X_train.npy')
X_test = np.load('../data/processed/X_test.npy')
y_train = np.load('../data/processed/y_train.npy')
y_test = np.load('../data/processed/y_test.npy')

# Train model
model, history = train_model(X_train, y_train, X_test, y_test)

# Plot training history
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Time')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Make predictions
y_pred = model.predict(X_test)

# Plot predictions vs actual
plt.figure(figsize=(12, 6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.title('Predictions vs Actual Values')
plt.xlabel('Time')
plt.ylabel('Scaled Price')
plt.legend()
plt.show()
# Out:
# 2024-12-18 16:17:54.810041: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-12-18 16:17:54.836525: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.8/lib64:/opt/spinnaker/lib:/home/rex/ros/catkin_ws/devel/lib:/opt/ros/noetic/lib:/opt/ros/noetic/lib/x86_64-linux-gnu:/home/rex/Documents/software_make/Linux_Software/Linux_Software/sFoundation/sFoundation/
# 2024-12-18 16:17:54.836541: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2024-12-18 16:17:54.836988: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/100
# 23/23 [==============================] - 4s 59ms/step - loss: 0.0259 - mae: 0.1159 - val_loss: 0.0996 - val_mae: 0.3045
# Epoch 2/100
# 23/23 [==============================] - 1s 35ms/step - loss: 0.0041 - mae: 0.0500 - val_loss: 0.0399 - val_mae: 0.1896
# Epoch 3/100
# 23/23 [==============================] - 1s 34ms/step - loss: 0.0030 - mae: 0.0429 - val_loss: 0.0238 - val_mae: 0.1427
# Epoch 4/100
# 23/23 [==============================] - 1s 34ms/step - loss: 0.0026 - mae: 0.0401 - val_loss: 0.0091 - val_mae: 0.0812
# Epoch 5/100
# 23/23 [==============================] - 1s 35ms/step - loss: 0.0023 - mae: 0.0371 - val_loss: 0.0160 - val_mae: 0.1147
# Epoch 6/100
# 23/23 [==============================] - 1s 34ms/step - loss: 0.0021 - mae: 0.0350 - val_loss: 0.0048 - val_mae: 0.0555
# Epoch 7/100
# 23/23 [==============================] - 1s 34ms/step - loss: 0.0019 - mae: 0.0342 - val_loss: 0.0076 - val_mae: 0.0742
# Epoch 8/100
# 23/23 [==============================] - 1s 34ms/step - loss: 0.0018 - mae: 0.0324 - val_loss: 0.0059 - val_mae: 0.0638
# Epoch 9/100
# 23/23 [==============================] - 1s 37ms/step - loss: 0.0019 - mae: 0.0333 - val_loss: 0.0054 - val_mae: 0.0602
# Epoch 10/100
# 23/23 [==============================] - 1s 36ms/step - loss: 0.0016 - mae: 0.0307 - val_loss: 0.0030 - val_mae: 0.0434
# Epoch 11/100
# 23/23 [==============================] - 1s 33ms/step - loss: 0.0016 - mae: 0.0303 - val_loss: 0.0034 - val_mae: 0.0467
# Epoch 12/100
# 23/23 [==============================] - 1s 33ms/step - loss: 0.0018 - mae: 0.0319 - val_loss: 0.0125 - val_mae: 0.0997
# Epoch 13/100
# 23/23 [==============================] - 1s 34ms/step - loss: 0.0018 - mae: 0.0321 - val_loss: 0.0054 - val_mae: 0.0593
# Epoch 14/100
# 23/23 [==============================] - 1s 33ms/step - loss: 0.0015 - mae: 0.0293 - val_loss: 0.0068 - val_mae: 0.0684
# Epoch 15/100
# 23/23 [==============================] - 1s 34ms/step - loss: 0.0013 - mae: 0.0284 - val_loss: 0.0046 - val_mae: 0.0552
# Epoch 16/100
# 23/23 [==============================] - 1s 34ms/step - loss: 0.0013 - mae: 0.0278 - val_loss: 0.0069 - val_mae: 0.0692
# Epoch 17/100
# 23/23 [==============================] - 1s 34ms/step - loss: 0.0014 - mae: 0.0278 - val_loss: 0.0072 - val_mae: 0.0712
# Epoch 18/100
# 23/23 [==============================] - 1s 33ms/step - loss: 0.0013 - mae: 0.0280 - val_loss: 0.0083 - val_mae: 0.0774
# Epoch 19/100
# 23/23 [==============================] - 1s 33ms/step - loss: 0.0013 - mae: 0.0273 - val_loss: 0.0072 - val_mae: 0.0715
# Epoch 20/100
# 23/23 [==============================] - 1s 33ms/step - loss: 0.0016 - mae: 0.0296 - val_loss: 0.0086 - val_mae: 0.0790
# 6/6 [==============================] - 1s 9ms/step

# %%
# Plot training history
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Time')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
